# %% [markdown]
# <a href="https://colab.research.google.com/github/shaalu2408-pixel/Python-module-4/blob/main/Python_Assignment_1_Data_Structures_Strings_%26_Tuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# STRINGS (CONCENTATION, SILICING AND OTHER METHODS)

# %% [markdown]
# 1. STRING CONCATENATION

# %% [markdown]
#  string 1 “Hello ”, string 2 get name as input from the user and concatenates them together.Display the concatenated string as
# the output

# %%
String1="Hello "
String2=input("Enter Your Name:")
Output=String1+String2
print(Output)
# Out:
# Enter Your Name:zara
# Hello zara

# %% [markdown]
# Now concatenate string 3 “, welcome to Python programming” to the existing string and
# display the output string

# %%
String3=", Welcome To Python Programming"
Output=Output+ ""+(String3)
print(Output)
# Out:
# Hello zara, Welcome To Python Programming

# %% [markdown]
# 2. STRING SLICING AND INDEXING

# %% [markdown]
# Print the first character of the string.

# %%
Output [0]
# Out:
# 'H'

# %% [markdown]
# Print the last character of the string.

# %%
Output [40]
# Out:
# 'g'

# %% [markdown]
# Print the first 5 characters of the string.

# %%
Output [0:5]
# Out:
# 'Hello'

# %% [markdown]
# Print the last 11 characters of the string.

# %%
Output [30:]
# Out:
# 'Programming'

# %% [markdown]
# Print the string in reverse.

# %%
Output [::-1]
# Out:
# 'gnimmargorP nohtyP oT emocleW ,araz olleH'

# %% [markdown]
# Use slicing and print the word “Python” from the existing string.

# %%
Output[23:29]
# Out:
# 'Python'

# %% [markdown]
# 3. STRING METHODS

# %% [markdown]
# Python program that takes a string, strM = “Python beginner tutorial”

# %%
strM = "Python beginner tutorial"
print(strM)
# Out:
# Python beginner tutorial

# %% [markdown]
# Convert the sentence to uppercase

# %%
strM.upper()
# Out:
# 'PYTHON BEGINNER TUTORIAL'

# %% [markdown]
# Convert the sentence to lowercase.

# %%
strM.lower()
# Out:
# 'python beginner tutorial'

# %% [markdown]
# Use Capitalize and return the sentence to the original input form.

# %%
strM.capitalize()
# Out:
# 'Python beginner tutorial'

# %% [markdown]
# Count the total number of occurrences of character ‘t’  in the string.

# %%
strM.count('t')
# Out:
# 3

# %% [markdown]
# Replace all occurrences of “Python” with “Machine Learning”  in the input string
# strM = “Python beginner tutorial”

# %%
strM.replace("Python","Machine Learning")
# Out:
# 'Machine Learning beginner tutorial'

# %% [markdown]
# TUPLES (CREATION, MODIFICATION AND ACCESS)

# %% [markdown]
# Create 1st tuple with values -> (10, 20, 30), 2nd tuple with values -> (40, 50, 60)

# %%
Tuple1st=(10,20,30)
print(Tuple1st)
type(Tuple1st)
# Out:
# (10, 20, 30)
# tuple

# %%
Tuple2nd=(40,50,60)
print(Tuple2nd)
type(Tuple2nd)
# Out:
# (40, 50, 60)
# tuple

# %% [markdown]
# Concatenate the two tuples and store it in “t_combine”

# %%
T_combine=Tuple1st+Tuple2nd
print(T_combine)
# Out:
# (10, 20, 30, 40, 50, 60)

# %% [markdown]
# Repeat the elements of “t_combine” 3 times

# %%
(T_combine)*3
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %% [markdown]
# Access the 3rd element from “t_combine”

# %%
T_combine[2]
# Out:
# 30

# %% [markdown]
# Access the first three elements from “t_combine”

# %%
T_combine[0:3]
# Out:
# (10, 20, 30)

# %% [markdown]
# Access the last three elements from “t_combine”

# %%
T_combine[3:]
# Out:
# (40, 50, 60)
