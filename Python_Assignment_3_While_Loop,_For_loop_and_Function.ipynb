# %% [markdown]
# <a href="https://colab.research.google.com/github/shaalu2408-pixel/Python-module-4/blob/main/Python_Assignment_3_While_Loop%2C_For_loop_and_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python Assignment 3: While Loop, For loop and Function**

# %% [markdown]
# While loop & Control Statements :
# (else, break, continue, pass)
#
# Number Guessing Game
#
# Problem Statement: Create a Python program that implements a simple number
# guessing game using a while loop. The program should make use of control
# statements such as else, break, and continue.

# %%
import random
secret_number= random.randint(1,10)
attempts = 3
while attempts >0:
  guess =int(input("Enter the number between 1 - 10 :") )
  if guess < 1 or guess >10:
              print("Your guess is out of range. Please guess a number between 1 and 10. ")
              continue
  if guess == secret_number:
              print("Congratulations! You guessed the correct number. ")
              break
  elif guess < secret_number:
              print("Too low. Try again.")
  else:
              print("Too high. Try again")
  attempts -= 1

else:
              print("Run out of attempts!! Please come back Later.")
# Out:
# Enter the number between 1 - 10 :2
# Too high. Try again
# Enter the number between 1 - 10 :5
# Too high. Try again
# Enter the number between 1 - 10 :7
# Too high. Try again
# Run out of attempts!! Please come back Later.

# %% [markdown]
# For Loop:
#
# Multiplication Table Generator
#
# Problem Statement: Create a Python program that generates and prints a
# multiplication table (from 1 to 10) for a given number using a for loop and the range
# function.

# %%
Number=int(input("Enter the number for which you want the multiplication table: "))
for i in range(1,11):
  print(f"{Number}x{i} = {Number*i}")
# Out:
# Enter the number for which you want the multiplication table: 12
# 12x1 = 12
# 12x2 = 24
# 12x3 = 36
# 12x4 = 48
# 12x5 = 60
# 12x6 = 72
# 12x7 = 84
# 12x8 = 96
# 12x9 = 108
# 12x10 = 120

# %% [markdown]
# Function:
#
# BMI Calculator
#
# Problem Statement: Create a Python program that calculates the Body Mass Index (BMI)

# %%
def BMI_calculate():

  w = float(input("Enter your {weight} in kg:"))
  h = float(input("Enter your {height}in meters:"))
  BMI = w / (h**2)
  print("Your BMI is:",round((BMI),2))
BMI_calculate()
# Out:
# Enter your {weight} in kg:58
# Enter your {height}in meters:1.62
# Your BMI is: 22.1
